# %%
from PIL import Image
import numpy as np
from torch.utils.data import Dataset

# %%
img = Image.open("./datasets/maps/test/3.jpg")
w, h = img.size
img = np.array(img)
width_cutoff = w // 2
s1 = Image.fromarray(img[:, :width_cutoff])
s2 = Image.fromarray(img[:, width_cutoff:])

# %%
s1
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7FAEFA9BF850>

# %%
s2
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7FAEFA9BFEB0>
